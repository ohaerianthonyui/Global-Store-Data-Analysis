# %% [markdown]
# # Exploratory Data Analysis (EDA) on the Global Superstore Database
#
# ## Problem Statement
#
# Sales Trends and Patterns: Identify the seasonal fluctuations and trends in sales across product categories and regions.
#
# Profitability Analysis: Analyze profit margins across product categories, customer segments, and regions to identify high-margin areas.
#
# Customer Segmentation: Segment customers based on purchasing behavior to identify valuable customer segments and their preferences.
#
# Product Performance: Assess the performance of products and categories to identify top-sellers and underperforming items.
#
# Regional Analysis: Evaluate sales and profitability across regions to identify growth opportunities and regional preferences.
#
# Shipping Dynamics: Analyze shipping preferences, delivery times, and costs to optimize logistics and improve customer satisfaction.
#
# Promotional Effectiveness: Evaluate the impact of promotions and discounts on sales and profitability.
#
# Return Analysis: Investigate return rates and reasons to minimize returns and improve product quality.

# %% [markdown]
# #### Import Necessary Libraries
#
# The code imports necessary libraries for data analysis and visualization, including pandas, numpy, matplotlib, and seaborn.
#
# Pandas is commonly used for data manipulation and analysis.
#
# NumPy is used for numerical computations.
#
# Matplotlib and Seaborn are popular libraries for data visualization.

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt     
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\Data Analysis Projects\Global_SuperStore_16.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Row ID                  Order ID  Order Date   Ship Date  \
# 0           0   40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014
# 1           1   26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014
# 2           2   25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014
# 3           3   13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014
# 4           4   47221   SG-2014-RH9495111-41948   11/5/2014   11/6/2014
#
#       Ship Mode   Customer ID     Customer Name      Segment  Postal Code  \
# 0   First Class  AB-100151402     Aaron Bergman     Consumer      73120.0
# 1  Second Class     JR-162107     Justin Ritter    Corporate          NaN
# 2   First Class     CR-127307      Craig Reiter     Consumer          NaN
# 3   First Class    KM-1637548  Katherine Murray  Home Office          NaN
# 4      Same Day    RH-9495111       Rick Hansen     Consumer          NaN
#
#    ...    Category Sub-Category                               Product Name  \
# 0  ...  Technology       Phones                           Samsung Convoy 3
# 1  ...   Furniture       Chairs  Novimex Executive Leather Armchair, Black
# 2  ...  Technology       Phones          Nokia Smart Phone, with Caller ID
# 3  ...  Technology       Phones             Motorola Smart Phone, Cordless
# 4  ...  Technology      Copiers             Sharp Wireless Fax, High-Speed
#
#       Sales Quantity Discount    Profit Shipping Cost Order Priority  Returned
# 0   221.980        2      0.0   62.1544         40.77           High       NaN
# 1  3709.395        9      0.1 -288.7650        923.63       Critical       NaN
# 2  5175.171        9      0.1  919.9710        915.49         Medium       NaN
# 3  2892.510        5      0.1  -96.5400        910.16         Medium       NaN
# 4  2832.960        8      0.0  311.5200        903.04       Critical       NaN
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Row ID', 'Order ID', 'Order Date', 'Ship Date',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Postal Code',
#        'City', 'State', 'Country', 'Region', 'Market', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'Returned'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51290 non-null  int64
#  1   Row ID          51290 non-null  int64
#  2   Order ID        51290 non-null  object
#  3   Order Date      51290 non-null  object
#  4   Ship Date       51290 non-null  object
#  5   Ship Mode       51290 non-null  object
#  6   Customer ID     51290 non-null  object
#  7   Customer Name   51290 non-null  object
#  8   Segment         51290 non-null  object
#  9   Postal Code     9994 non-null   float64
#  10  City            51290 non-null  object
#  11  State           51290 non-null  object
#  12  Country         51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Market          51290 non-null  object
#  15  Product ID      51290 non-null  object
#  16  Category        51290 non-null  object
#  17  Sub-Category    51290 non-null  object
#  18  Product Name    51290 non-null  object
#  19  Sales           51290 non-null  float64
#  20  Quantity        51290 non-null  int64
#  21  Discount        51290 non-null  float64
#  22  Profit          51290 non-null  float64
#  23  Shipping Cost   51290 non-null  float64
#  24  Order Priority  51290 non-null  object
#  25  Returned        2202 non-null   object
# dtypes: float64(5), int64(3), object(18)
# memory usage: 10.2+ MB

# %% [markdown]
# DataFrame Information:
#
# The DataFrame 'df' contains 51,290 entries across 25 columns.
# Column names and their respective data types are displayed.
# Several columns contain non-null values, while others have missing values (e.g., 'Postal Code' and 'Returned').
# 'Order Date' and 'Ship Date' columns are datetime objects, likely representing the date and time of order and shipment.
# Numeric columns include 'Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit', and 'Shipping Cost'.
# Object type columns include 'Order ID', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country', 'Region', 'Market', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Order Priority', and 'Returned'.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# Returned          49088
# dtype: int64

# %% [markdown]
# The 'Postal Code' column has a significant number of missing values, and the 'Returned' column also has a considerable number of missing values.
# The 'Postal Code' column doess no tseem  essential for my analysis, I am going to drop it altogether.
# I plan to replace missing values with a specific category like 'No' if orders were not returned.

# %%
## Cheking for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
## Data Removal

## Removes several columns from the 'df' DataFrame

df.drop(['Row ID', 'Order ID', 'Ship Date', 'Customer ID', 'Postal Code', 'Product Name'], axis=1, inplace = True)

# %%
## Fill the missing values in the 'Returned' column of the 'df' DataFrame with the string 'No'

df['Returned'].fillna('No', inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Order Date        0
# Ship Mode         0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Region            0
# Market            0
# Product ID        0
# Category          0
# Sub-Category      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# Returned          0
# dtype: int64

# %% [markdown]
# ## Feature Engineering
#
# ### Adding several new columns to the 'df' DataFrame from the metrics:
#
# 'Year': Extracted from the 'Order Date' column, representing the year of the order.
#
# 'Month': Extracted from the 'Order Date' column, representing the month of the order.
#
# 'Cost': Calculated as the difference between 'Sales' and 'Profit', representing the cost incurred.
#
# 'Total Amount': Calculated as the sum of 'Sales' and 'Shipping Cost', representing the total amount including shipping cost.

# %%
# New column
## Convert Order Date to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])

## EXtract the year and month to create a new column
df['Year'] = df['Order Date'].dt.year

df['Month'] = df['Order Date'].dt.month

# %%
# Extracting the total revenue generated from sales.
df['Total Sales'] = df['Sales'] * df['Quantity']

# The total profit generated from sales.
df['Total Profit'] = df['Profit'] * df['Quantity']

# The total cost incurred for shipping.
df['Total Shipping Cost'] = df['Shipping Cost'] * df['Quantity']

# %%
## Checking for the changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           51290 non-null  int64
#  1   Order Date           51290 non-null  datetime64[ns]
#  2   Ship Mode            51290 non-null  object
#  3   Customer Name        51290 non-null  object
#  4   Segment              51290 non-null  object
#  5   City                 51290 non-null  object
#  6   State                51290 non-null  object
#  7   Country              51290 non-null  object
#  8   Region               51290 non-null  object
#  9   Market               51290 non-null  object
#  10  Product ID           51290 non-null  object
#  11  Category             51290 non-null  object
#  12  Sub-Category         51290 non-null  object
#  13  Sales                51290 non-null  float64
#  14  Quantity             51290 non-null  int64
#  15  Discount             51290 non-null  float64
#  16  Profit               51290 non-null  float64
#  17  Shipping Cost        51290 non-null  float64
#  18  Order Priority       51290 non-null  object
#  19  Returned             51290 non-null  object
#  20  Year                 51290 non-null  int32
#  21  Month                51290 non-null  int32
#  22  Total Sales          51290 non-null  float64
#  23  Total Profit         51290 non-null  float64
#  24  Total Shipping Cost  51290 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int32(2), int64(2), object(13)
# memory usage: 9.4+ MB

# %%
## Summary Statistics
df.describe().T
# Out:
#                        count                           mean  \
# Unnamed: 0           51290.0                        25644.5
# Order Date             51290  2014-05-11 21:26:49.155780608
# Sales                51290.0                     246.490581
# Quantity             51290.0                       3.476545
# Discount             51290.0                       0.142908
# Profit               51290.0                      28.610982
# Shipping Cost        51290.0                      26.478567
# Year                 51290.0                    2013.777208
# Month                51290.0                       7.516027
# Total Sales          51290.0                    1205.327987
# Total Profit         51290.0                     140.928945
# Total Shipping Cost  51290.0                     127.513488
#
#                                      min                  25%  \
# Unnamed: 0                           0.0             12822.25
# Order Date           2012-01-01 00:00:00  2013-06-19 00:00:00
# Sales                              0.444            30.758625
# Quantity                             1.0                  2.0
# Discount                             0.0                  0.0
# Profit                         -6599.978                  0.0
# Shipping Cost                      1.002                 2.61
# Year                              2012.0               2013.0
# Month                                1.0                  5.0
# Total Sales                        0.444                66.93
# Total Profit                  -49060.512                  0.0
# Total Shipping Cost                 1.01                  6.2
#
#                                      50%                  75%  \
# Unnamed: 0                       25644.5             38466.75
# Order Date           2014-07-08 00:00:00  2015-05-22 00:00:00
# Sales                             85.053             251.0532
# Quantity                             3.0                  5.0
# Discount                             0.0                  0.2
# Profit                              9.24                36.81
# Shipping Cost                       7.79                24.45
# Year                              2014.0               2015.0
# Month                                8.0                 10.0
# Total Sales                      245.772              904.875
# Total Profit                     22.6515               123.12
# Total Shipping Cost                22.64              87.3575
#
#                                      max          std
# Unnamed: 0                       51289.0  14806.29199
# Order Date           2015-12-31 00:00:00          NaN
# Sales                           22638.48   487.565361
# Quantity                            14.0     2.278766
# Discount                            0.85      0.21228
# Profit                          8399.976   174.340972
# Shipping Cost                     933.57    57.251373
# Year                              2015.0     1.098931
# Month                               12.0     3.300526
# Total Sales                    135830.88  3452.079528
# Total Profit                    64302.81  1204.325089
# Total Shipping Cost             11254.62   385.804489

# %%
## Segmenting columns into Categorical and Numerical
cat_col = df.select_dtypes(include='object').columns.tolist()
num_col = df.select_dtypes(include=np.number).columns.tolist()

print(cat_col)
print(num_col)
# Out:
# ['Ship Mode', 'Customer Name', 'Segment', 'City', 'State', 'Country', 'Region', 'Market', 'Product ID', 'Category', 'Sub-Category', 'Order Priority', 'Returned']
# ['Unnamed: 0', 'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost', 'Year', 'Month', 'Total Sales', 'Total Profit', 'Total Shipping Cost']

# %%
## Using a for loop to iterate the numerical column to display the distribution

for col in num_col:
    plt.subplot(1,1,1)
    df[col].hist(bins=20, alpha=0.5, grid=False)
    plt.ylabel('Frequency')
    plt.title(col)
    plt.show()

# %% [markdown]
# Most orders consist of 1 to 5 items, with 2 being the most common quantity.
#
# Discounts of 20%, 10%, 40%, and 60% are among the most common.
#
# Profits vary widely, ranging from significant profits to losses. A considerable number of orders result in zero profit.
#
# Most common shipping costs include  1.35, 1.97, 1.79, 1.80, and $1.62
#
# Orders are distributed across the years 2012 to 2015, with 2015 having the highest number of orders
#
# Orders are spread across different months, with November and December having the highest number of orders.

# %%
## Using a for loop to iterate the categorical column to display the distribution
for col in cat_col:
    plt.figure()  # Adjust the figsize as needed
    sns.countplot(x=col, data=df, order=df[col].value_counts().head(10).index, palette='Set1')
    plt.xticks(rotation=90)
    plt.title(col)
    plt.show()

# %% [markdown]
# The provided series of value counts represents the distribution of various categorical variables in the dataset.
#
# Most orders are shipped using "Standard Class" (30,775 orders), followed by "Second Class" (10,309 orders), "First Class" (7,505 orders), and "Same Day" (2,701 orders).
#
# The majority of orders are from the "Consumer" segment (26,518 orders), followed by "Corporate" (15,429 orders), and "Home Office" (9,343 orders).
#
# The dataset includes orders from different countries, with the majority from the "United States" (9,994 orders).
#
# Orders are from different states, with "California" having the highest number of orders (2,001 orders).
#
# Orders are distributed across different regions, with "Western Europe" having the highest number of orders (5,883 orders).
#
# The market is segmented into different regions, with "Asia Pacific" having the highest number of orders (14,302 orders).
#
# Most orders are for "Office Supplies" (31,289 orders), followed by "Technology" (10,141 orders), and "Furniture" (9,860 orders).

# %% [markdown]
# ## Analysis on the Metrics and KPIs

# %%
# Set the display format for floating point numbers
pd.options.display.float_format = '{:,.2f}'.format

# %%
## Net sales
print(f'Net Sales {df['Sales'].sum()}')
# Out:
# Net Sales 12642501.90988

# %%
# Net Profit
print(f'Net Profit {df['Profit'].sum()}')
# Out:
# Net Profit 1467457.29128

# %%
print(f'Gross Sales {df['Total Sales'].sum()}')
# Out:
# Gross Sales 61821272.47008

# %%
print(f'Gross Profit {df['Total Profit'].sum()}')
# Out:
# Gross Profit 7228245.595880001

# %%
## Profit margin =  Total profit / Total Sales
# Format as percentage
print(f'Profit Margin {round(df['Total Profit'].sum()/df['Total Sales'].sum() * 100)} %')
# Out:
# Profit Margin 12 %

# %%
##Total cost = Total Sales / Total Profit - Total Shipping Cost

print(f'Total Cost {df['Total Sales'].sum() - df['Total Profit'].sum() - df['Total Shipping Cost'].sum()}')
# Out:
# Total Cost 48052860.08724

# %%
## Net Profit = Total Profit - Total Shipping Cost

print(f'Net Profit {df['Total Profit'].sum() - df['Total Shipping Cost'].sum()}')
# Out:
# Net Profit 688078.8089200007

# %%
# Grouping the data by month to calculate sum of sales, profit and quantity. This shows the annual KPIs
year_analysis = df.groupby('Year').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).reset_index()

# %%
year_analysis.style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_1d945_row0_col0, #T_1d945_row0_col1, #T_1d945_row0_col2, #T_1d945_row0_col3 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_1d945_row1_col0 {
#   background-color: #e7cf94;
#   color: #000000;
# }
# #T_1d945_row1_col1 {
#   background-color: #c08430;
#   color: #f1f1f1;
# }
# #T_1d945_row1_col2, #T_1d945_row1_col3 {
#   background-color: #c89343;
#   color: #f1f1f1;
# }
# #T_1d945_row2_col0 {
#   background-color: #98d7cd;
#   color: #000000;
# }
# #T_1d945_row2_col1 {
#   background-color: #d9eeeb;
#   color: #000000;
# }
# #T_1d945_row2_col2 {
#   background-color: #b9e4de;
#   color: #000000;
# }
# #T_1d945_row2_col3 {
#   background-color: #d4ede9;
#   color: #000000;
# }
# #T_1d945_row3_col0, #T_1d945_row3_col1, #T_1d945_row3_col2, #T_1d945_row3_col3 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1d945">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d945_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_1d945_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_1d945_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_1d945_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d945_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1d945_row0_col0" class="data row0 col0" >2012</td>
#       <td id="T_1d945_row0_col1" class="data row0 col1" >2259450.895540</td>
#       <td id="T_1d945_row0_col2" class="data row0 col2" >248940.811540</td>
#       <td id="T_1d945_row0_col3" class="data row0 col3" >31443</td>
#     </tr>
#     <tr>
#       <th id="T_1d945_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1d945_row1_col0" class="data row1 col0" >2013</td>
#       <td id="T_1d945_row1_col1" class="data row1 col1" >2677438.694400</td>
#       <td id="T_1d945_row1_col2" class="data row1 col2" >307415.279100</td>
#       <td id="T_1d945_row1_col3" class="data row1 col3" >38111</td>
#     </tr>
#     <tr>
#       <th id="T_1d945_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1d945_row2_col0" class="data row2 col0" >2014</td>
#       <td id="T_1d945_row2_col1" class="data row2 col1" >3405746.449380</td>
#       <td id="T_1d945_row2_col2" class="data row2 col2" >406935.230180</td>
#       <td id="T_1d945_row2_col3" class="data row2 col3" >48136</td>
#     </tr>
#     <tr>
#       <th id="T_1d945_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1d945_row3_col0" class="data row3 col0" >2015</td>
#       <td id="T_1d945_row3_col1" class="data row3 col1" >4299865.870560</td>
#       <td id="T_1d945_row3_col2" class="data row3 col2" >504165.970460</td>
#       <td id="T_1d945_row3_col3" class="data row3 col3" >60622</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plotting the data
plt.figure(figsize=(12, 6))


# Sales plot
plt.subplot(2, 2, 1)
plt.bar(year_analysis['Year'], year_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks([2012,2013,2014,2015])
plt.title('Total Sales by Year')
plt.xlabel('Year')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.bar(year_analysis['Year'], year_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks([2012,2013,2014,2015])
plt.title('Total Profit by Year')
plt.xlabel('Year')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.bar(year_analysis['Year'], year_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks([2012,2013,2014,2015])
plt.title('Total Quantity Sold by Year')
plt.xlabel('Year')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Sales and profit show an increasing trend over the years, indicating positive growth in business activities.
#
# The most significant growth is observed between 2014 and 2015, with both sales and profit substantially increasing.

# %%
# Group data by month and calculate sum of Sales, Profit and Quantity
monthly_data = df.groupby('Month').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).reset_index()

# %%
monthly_data.style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_b0a73_row0_col0, #T_b0a73_row0_col1, #T_b0a73_row1_col2, #T_b0a73_row1_col3 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_b0a73_row0_col2 {
#   background-color: #015b52;
#   color: #f1f1f1;
# }
# #T_b0a73_row0_col3 {
#   background-color: #004135;
#   color: #f1f1f1;
# }
# #T_b0a73_row1_col0 {
#   background-color: #016259;
#   color: #f1f1f1;
# }
# #T_b0a73_row1_col1 {
#   background-color: #004439;
#   color: #f1f1f1;
# }
# #T_b0a73_row2_col0 {
#   background-color: #6abdb2;
#   color: #000000;
# }
# #T_b0a73_row2_col1 {
#   background-color: #12766e;
#   color: #f1f1f1;
# }
# #T_b0a73_row2_col2 {
#   background-color: #01554b;
#   color: #f1f1f1;
# }
# #T_b0a73_row2_col3 {
#   background-color: #0e726a;
#   color: #f1f1f1;
# }
# #T_b0a73_row3_col0 {
#   background-color: #aee0d8;
#   color: #000000;
# }
# #T_b0a73_row3_col1 {
#   background-color: #67bbb0;
#   color: #000000;
# }
# #T_b0a73_row3_col2 {
#   background-color: #3b9b93;
#   color: #f1f1f1;
# }
# #T_b0a73_row3_col3 {
#   background-color: #8dd2c7;
#   color: #000000;
# }
# #T_b0a73_row4_col0 {
#   background-color: #f5efde;
#   color: #000000;
# }
# #T_b0a73_row4_col1, #T_b0a73_row4_col2 {
#   background-color: #81cec2;
#   color: #000000;
# }
# #T_b0a73_row4_col3 {
#   background-color: #79c8bc;
#   color: #000000;
# }
# #T_b0a73_row5_col0 {
#   background-color: #2b8d85;
#   color: #f1f1f1;
# }
# #T_b0a73_row5_col1 {
#   background-color: #b6e3dd;
#   color: #000000;
# }
# #T_b0a73_row5_col2 {
#   background-color: #23867e;
#   color: #f1f1f1;
# }
# #T_b0a73_row5_col3 {
#   background-color: #cbebe6;
#   color: #000000;
# }
# #T_b0a73_row6_col0 {
#   background-color: #eedbaa;
#   color: #000000;
# }
# #T_b0a73_row6_col1 {
#   background-color: #ecd8a5;
#   color: #000000;
# }
# #T_b0a73_row6_col2 {
#   background-color: #e6cd92;
#   color: #000000;
# }
# #T_b0a73_row6_col3 {
#   background-color: #f2e2b8;
#   color: #000000;
# }
# #T_b0a73_row7_col0 {
#   background-color: #b57826;
#   color: #f1f1f1;
# }
# #T_b0a73_row7_col1, #T_b0a73_row9_col3 {
#   background-color: #c08430;
#   color: #f1f1f1;
# }
# #T_b0a73_row7_col2 {
#   background-color: #b77928;
#   color: #f1f1f1;
# }
# #T_b0a73_row7_col3 {
#   background-color: #bd7f2c;
#   color: #f1f1f1;
# }
# #T_b0a73_row8_col0 {
#   background-color: #e0f0ee;
#   color: #000000;
# }
# #T_b0a73_row8_col1 {
#   background-color: #bb7d2a;
#   color: #f1f1f1;
# }
# #T_b0a73_row8_col2 {
#   background-color: #663a07;
#   color: #f1f1f1;
# }
# #T_b0a73_row8_col3 {
#   background-color: #cc9a4c;
#   color: #f1f1f1;
# }
# #T_b0a73_row9_col0 {
#   background-color: #d6af65;
#   color: #000000;
# }
# #T_b0a73_row9_col1 {
#   background-color: #9f6317;
#   color: #f1f1f1;
# }
# #T_b0a73_row9_col2 {
#   background-color: #583305;
#   color: #f1f1f1;
# }
# #T_b0a73_row10_col0, #T_b0a73_row11_col1, #T_b0a73_row11_col2, #T_b0a73_row11_col3 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_b0a73_row10_col1 {
#   background-color: #955910;
#   color: #f1f1f1;
# }
# #T_b0a73_row10_col2 {
#   background-color: #563105;
#   color: #f1f1f1;
# }
# #T_b0a73_row10_col3 {
#   background-color: #894f0a;
#   color: #f1f1f1;
# }
# #T_b0a73_row11_col0 {
#   background-color: #874e0a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b0a73">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0a73_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_b0a73_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_b0a73_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_b0a73_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0a73_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0a73_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_b0a73_row0_col1" class="data row0 col1" >1566662.447500</td>
#       <td id="T_b0a73_row0_col2" class="data row0 col2" >168101.707100</td>
#       <td id="T_b0a73_row0_col3" class="data row0 col3" >22147</td>
#     </tr>
#     <tr>
#       <th id="T_b0a73_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b0a73_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_b0a73_row1_col1" class="data row1 col1" >1546728.156160</td>
#       <td id="T_b0a73_row1_col2" class="data row1 col2" >175983.189460</td>
#       <td id="T_b0a73_row1_col3" class="data row1 col3" >22379</td>
#     </tr>
#     <tr>
#       <th id="T_b0a73_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b0a73_row2_col0" class="data row2 col0" >9</td>
#       <td id="T_b0a73_row2_col1" class="data row2 col1" >1431753.403480</td>
#       <td id="T_b0a73_row2_col2" class="data row2 col2" >169705.822080</td>
#       <td id="T_b0a73_row2_col3" class="data row2 col3" >20479</td>
#     </tr>
#     <tr>
#       <th id="T_b0a73_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b0a73_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_b0a73_row3_col1" class="data row3 col1" >1294314.957820</td>
#       <td id="T_b0a73_row3_col2" class="data row3 col2" >154593.439420</td>
#       <td id="T_b0a73_row3_col3" class="data row3 col3" >17596</td>
#     </tr>
#     <tr>
#       <th id="T_b0a73_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b0a73_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_b0a73_row4_col1" class="data row4 col1" >1262080.916940</td>
#       <td id="T_b0a73_row4_col2" class="data row4 col2" >144604.768440</td>
#       <td id="T_b0a73_row4_col3" class="data row4 col3" >18009</td>
#     </tr>
#     <tr>
#       <th id="T_b0a73_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b0a73_row5_col0" class="data row5 col0" >10</td>
#       <td id="T_b0a73_row5_col1" class="data row5 col1" >1185227.689720</td>
#       <td id="T_b0a73_row5_col2" class="data row5 col2" >158903.895920</td>
#       <td id="T_b0a73_row5_col3" class="data row5 col3" >16303</td>
#     </tr>
#     <tr>
#       <th id="T_b0a73_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b0a73_row6_col0" class="data row6 col0" >5</td>
#       <td id="T_b0a73_row6_col1" class="data row6 col1" >915492.830880</td>
#       <td id="T_b0a73_row6_col2" class="data row6 col2" >106970.037880</td>
#       <td id="T_b0a73_row6_col3" class="data row6 col3" >13196</td>
#     </tr>
#     <tr>
#       <th id="T_b0a73_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b0a73_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_b0a73_row7_col1" class="data row7 col1" >760517.975960</td>
#       <td id="T_b0a73_row7_col2" class="data row7 col2" >91873.579660</td>
#       <td id="T_b0a73_row7_col3" class="data row7 col3" >10390</td>
#     </tr>
#     <tr>
#       <th id="T_b0a73_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b0a73_row8_col0" class="data row8 col0" >7</td>
#       <td id="T_b0a73_row8_col1" class="data row8 col1" >752306.302220</td>
#       <td id="T_b0a73_row8_col2" class="data row8 col2" >76525.695020</td>
#       <td id="T_b0a73_row8_col3" class="data row8 col3" >11046</td>
#     </tr>
#     <tr>
#       <th id="T_b0a73_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b0a73_row9_col0" class="data row9 col0" >4</td>
#       <td id="T_b0a73_row9_col1" class="data row9 col1" >695978.410840</td>
#       <td id="T_b0a73_row9_col2" class="data row9 col2" >73822.418640</td>
#       <td id="T_b0a73_row9_col3" class="data row9 col3" >10466</td>
#     </tr>
#     <tr>
#       <th id="T_b0a73_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b0a73_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_b0a73_row10_col1" class="data row10 col1" >676788.927040</td>
#       <td id="T_b0a73_row10_col2" class="data row10 col2" >73440.459440</td>
#       <td id="T_b0a73_row10_col3" class="data row10 col3" >8872</td>
#     </tr>
#     <tr>
#       <th id="T_b0a73_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b0a73_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_b0a73_row11_col1" class="data row11 col1" >554649.891320</td>
#       <td id="T_b0a73_row11_col2" class="data row11 col2" >72932.278220</td>
#       <td id="T_b0a73_row11_col3" class="data row11 col3" >7429</td>
#     </tr>
#   </

# %%
 #Plotting the data
plt.figure(figsize=(12, 6))

# Sales plot
plt.subplot(2, 2, 1)
plt.plot(monthly_data['Month'], monthly_data['Sales'], marker='o')
plt.title('Total Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.plot(monthly_data['Month'], monthly_data['Profit'], marker='o')
plt.title('Total Profit by Month')
plt.xlabel('Month')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.plot(monthly_data['Month'], monthly_data['Quantity'], marker='o')
plt.title('Total Quantity Sold by Month')
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# The analysis reveals seasonal trends, with higher sales and profit observed during the end of the year, the holiday months of November and December.
#
# Sales tend to decline in the early months of the year, possibly due to post-holiday lull and reduced consumer spending.

# %%
# Group the data by ship mode to calculate the sum of Sales, Profit and Quantity
Ship_Mode_analysis = df.groupby('Ship Mode').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).reset_index()

# %%
Ship_Mode_analysis.sort_values(by='Sales', ascending=False).style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_81c02_row0_col1, #T_81c02_row0_col2, #T_81c02_row0_col3 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_81c02_row1_col1 {
#   background-color: #d7b169;
#   color: #000000;
# }
# #T_81c02_row1_col2 {
#   background-color: #d4ac62;
#   color: #000000;
# }
# #T_81c02_row1_col3 {
#   background-color: #d6af65;
#   color: #000000;
# }
# #T_81c02_row2_col1, #T_81c02_row2_col3 {
#   background-color: #af7222;
#   color: #f1f1f1;
# }
# #T_81c02_row2_col2 {
#   background-color: #ab6e1f;
#   color: #f1f1f1;
# }
# #T_81c02_row3_col1, #T_81c02_row3_col2, #T_81c02_row3_col3 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_81c02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81c02_level0_col0" class="col_heading level0 col0" >Ship Mode</th>
#       <th id="T_81c02_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_81c02_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_81c02_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81c02_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_81c02_row0_col0" class="data row0 col0" >Standard Class</td>
#       <td id="T_81c02_row0_col1" class="data row0 col1" >7578652.106700</td>
#       <td id="T_81c02_row0_col2" class="data row0 col2" >890596.021200</td>
#       <td id="T_81c02_row0_col3" class="data row0 col3" >107319</td>
#     </tr>
#     <tr>
#       <th id="T_81c02_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_81c02_row1_col0" class="data row1 col0" >Second Class</td>
#       <td id="T_81c02_row1_col1" class="data row1 col1" >2565671.681080</td>
#       <td id="T_81c02_row1_col2" class="data row1 col2" >292583.527080</td>
#       <td id="T_81c02_row1_col3" class="data row1 col3" >35724</td>
#     </tr>
#     <tr>
#       <th id="T_81c02_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_81c02_row2_col0" class="data row2 col0" >First Class</td>
#       <td id="T_81c02_row2_col1" class="data row2 col1" >1830976.138200</td>
#       <td id="T_81c02_row2_col2" class="data row2 col2" >208104.675200</td>
#       <td id="T_81c02_row2_col3" class="data row2 col3" >26039</td>
#     </tr>
#     <tr>
#       <th id="T_81c02_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_81c02_row3_col0" class="data row3 col0" >Same Day</td>
#       <td id="T_81c02_row3_col1" class="data row3 col1" >667201.983900</td>
#       <td id="T_81c02_row3_col2" class="data row3 col2" >76173.067800</td>
#       <td id="T_81c02_row3_col3" class="data row3 col3" >9230</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plotting
plt.figure(figsize=(12, 8))


# Sales plot
plt.subplot(2, 2, 1)
plt.bar(Ship_Mode_analysis['Ship Mode'], Ship_Mode_analysis['Sales'], color=sns.color_palette('Set1'))
plt.title('Total Sales by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.bar(Ship_Mode_analysis['Ship Mode'], Ship_Mode_analysis['Profit'], color=sns.color_palette('Set2'))
plt.title('Total Profit by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.bar(Ship_Mode_analysis['Ship Mode'], Ship_Mode_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.title('Total Quantity by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Standard Class seems to be the most preferred shipping option. This may likelybe due to its balance between cost and delivery speed.
#
# Same Day shipping, while accounting for fewer orders, caters to customers with urgent delivery requirements and contributes to overall customer satisfaction.

# %%
 # Grouping the  data by segment and calculate sum of Sales, Profit and Quantity
Segment_analysis = df.groupby('Segment').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).reset_index()

# %%
Segment_analysis.sort_values(by='Sales',ascending=False).style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_cf6c1_row0_col1, #T_cf6c1_row0_col2, #T_cf6c1_row0_col3 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_cf6c1_row1_col1 {
#   background-color: #edd9a8;
#   color: #000000;
# }
# #T_cf6c1_row1_col2 {
#   background-color: #ead59f;
#   color: #000000;
# }
# #T_cf6c1_row1_col3 {
#   background-color: #ebd6a2;
#   color: #000000;
# }
# #T_cf6c1_row2_col1, #T_cf6c1_row2_col2, #T_cf6c1_row2_col3 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cf6c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf6c1_level0_col0" class="col_heading level0 col0" >Segment</th>
#       <th id="T_cf6c1_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_cf6c1_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_cf6c1_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf6c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf6c1_row0_col0" class="data row0 col0" >Consumer</td>
#       <td id="T_cf6c1_row0_col1" class="data row0 col1" >6507949.417860</td>
#       <td id="T_cf6c1_row0_col2" class="data row0 col2" >749239.782060</td>
#       <td id="T_cf6c1_row0_col3" class="data row0 col3" >92157</td>
#     </tr>
#     <tr>
#       <th id="T_cf6c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cf6c1_row1_col0" class="data row1 col0" >Corporate</td>
#       <td id="T_cf6c1_row1_col1" class="data row1 col1" >3824697.521460</td>
#       <td id="T_cf6c1_row1_col2" class="data row1 col2" >441208.328660</td>
#       <td id="T_cf6c1_row1_col3" class="data row1 col3" >53565</td>
#     </tr>
#     <tr>
#       <th id="T_cf6c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cf6c1_row2_col0" class="data row2 col0" >Home Office</td>
#       <td id="T_cf6c1_row2_col1" class="data row2 col1" >2309854.970560</td>
#       <td id="T_cf6c1_row2_col2" class="data row2 col2" >277009.180560</td>
#       <td id="T_cf6c1_row2_col3" class="data row2 col3" >32590</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plotting
plt.figure(figsize=(12, 8))

# Sales plot
plt.subplot(2, 2, 1)
plt.bar(Segment_analysis['Segment'], Segment_analysis['Sales'], color=sns.color_palette('Set1'))
plt.title('Total Sales by Segment')
plt.xlabel('Segment')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.bar(Segment_analysis['Segment'], Segment_analysis['Profit'], color=sns.color_palette('Set2'))
plt.title('Total Profit by Segment')
plt.xlabel('Segment')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.bar(Segment_analysis['Segment'], Segment_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.title('Total Quantity by Segmente')
plt.xlabel('Segment')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Consumer segment seems to be the primary revenue generator, indicating a large and loyal customer base.
#
# Corporate segment contributes significantly to sales and profit, underscoring the importance of B2B relationships and bulk purchases.
#
# Home Office segment represents a niche market with moderate sales but high-profit margins, suggesting opportunities for targeted marketing and product offerings tailored to this demographic.

# %%
# Group data by City nth and calculate sum of Sales, Profit and Quantity
City_analysis = df.groupby('City').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).head(10).reset_index()

# %%
City_analysis
# Out:
#             City      Sales     Profit  Quantity
# 0  New York City 256,368.16  62,036.98      3417
# 1    Los Angeles 175,851.34  30,440.76      2879
# 2         Manila 120,886.95 -11,158.56      1661
# 3        Seattle 119,540.74  29,156.10      1590
# 4  San Francisco 112,669.09  17,507.39      1935
# 5   Philadelphia 109,077.01 -13,837.77      1981
# 6         Sydney 101,945.52  16,002.81       975
# 7        Jakarta  94,321.32   3,826.98      1226
# 8         London  86,945.80  17,378.72      1033
# 9    Mexico City  85,700.25  13,335.59      1138

# %%
# Plotting
plt.figure(figsize=(12, 8))

# Sales plot
plt.subplot(2, 2, 1)
plt.bar(City_analysis['City'], City_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks(rotation=90)
plt.title('Total Sales by City')
plt.xlabel('City')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.bar(City_analysis['City'], City_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks(rotation=90)
plt.title('Total Profit by City')
plt.xlabel('City')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.bar(City_analysis['City'], City_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks(rotation=90)
plt.title('Total Quantity by City')
plt.xlabel('City')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Certain cities like New York City, Los Angeles, and San Francisco emerge as key revenue generators, indicating their importance in the company's sales strategy.
#
# Negative profit in cities like Manila and Philadelphia suggests the need for operational improvements or pricing adjustments to ensure profitability.
#
# Understanding sales and profit by city can inform targeted marketing efforts, pricing strategies, and operational decisions to optimize performance in different markets.

# %%
# Group data by State and calculate sum of Sales, Profit and Quantity
State_analysis =df.groupby('State').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).head(10).reset_index()

# %%
State_analysis
# Out:
#                     State      Sales     Profit  Quantity
# 0                 England 485,170.97  99,907.73      5656
# 1              California 457,687.63  76,381.39      7667
# 2           Ile-de-France 317,822.54  44,055.92      3839
# 3                New York 310,876.27  74,038.55      4224
# 4         New South Wales 270,487.10  43,695.98      2921
# 5              Queensland 238,312.73  21,608.75      2665
# 6  North Rhine-Westphalia 216,451.85  42,347.87      2660
# 7                   Texas 170,188.05 -25,729.36      3724
# 8            San Salvador 153,639.40  35,883.38      2273
# 9        National Capital 152,175.36 -13,066.08      2231

# %%
# Plotting
plt.figure(figsize=(12, 8))

# Sales plot
plt.subplot(2, 2, 1)
plt.bar(State_analysis['State'], State_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks(rotation=90)
plt.title('Total Sales by State')
plt.xlabel('State')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.bar(State_analysis['State'], State_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks(rotation=90)
plt.title('Total Profit by State')
plt.xlabel('State')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.bar(State_analysis['State'], State_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks(rotation=90)
plt.title('Total Quantity by State')
plt.xlabel('State')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Certain states like England, California, and New York emerge as key revenue drivers, indicating their importance in the company's sales strategy.
#
# Negative profit margins in markets like Texas and National Capital underscore the need for operational improvements or pricing adjustments to ensure profitability.

# %%
##  Group data by Country and calculate sum of Sales, Profit and Quantity
Country_analysis = df.groupby('Country').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).head(10).reset_index()

# %%
Country_analysis
# Out:
#           Country        Sales     Profit  Quantity
# 0   United States 2,297,200.86 286,397.02     37873
# 1       Australia   925,235.85 103,907.43     10673
# 2          France   858,931.08 109,029.00     10804
# 3           China   700,562.03 150,683.08      7081
# 4         Germany   628,136.19 107,190.33      7739
# 5          Mexico   621,552.65 102,453.59      9972
# 6           India   589,486.04 129,050.60      5755
# 7  United Kingdom   528,576.30 111,900.15      6161
# 8       Indonesia   404,887.50  15,608.68      5237
# 9          Brazil   359,924.86  29,686.90      6123

# %%
# Plotting
plt.figure(figsize=(12, 8))

# Sales plot
plt.subplot(2, 2, 1)
plt.bar(Country_analysis['Country'], Country_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks(rotation=90)
plt.title('Total Sales by Country')
plt.xlabel('Country')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.bar(Country_analysis['Country'], Country_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks(rotation=90)
plt.title('Total Profit by Country')
plt.xlabel('Country')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.bar(Country_analysis['Country'], Country_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks(rotation=90)
plt.title('Total Quantity by Country')
plt.xlabel('Country')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# The United States emerges as the primary revenue driver, indicating its critical importance in the company's sales strategy and market dominance.
#
# High-profit margins in countries like Australia, China, and India suggest opportunities for growth and expansion in these markets.
#
# Understanding sales and profit by country can inform international expansion strategies, resource allocation, and market-specific initiatives to optimize performance and maximize profitability.

# %%
##  Group data by Market and calculate sum of Sales, Profit and Quantity

Market_analysis = df.groupby('Market').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).reset_index()

# %%
Market_analysis.sort_values(by='Sales', ascending=False).style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_732b4_row0_col1, #T_732b4_row0_col3, #T_732b4_row1_col2 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_732b4_row0_col2 {
#   background-color: #0e726a;
#   color: #f1f1f1;
# }
# #T_732b4_row1_col1 {
#   background-color: #4da89f;
#   color: #f1f1f1;
# }
# #T_732b4_row1_col3 {
#   background-color: #278a82;
#   color: #f1f1f1;
# }
# #T_732b4_row2_col1 {
#   background-color: #f5f3ee;
#   color: #000000;
# }
# #T_732b4_row2_col2 {
#   background-color: #c9eae6;
#   color: #000000;
# }
# #T_732b4_row2_col3 {
#   background-color: #61b7ac;
#   color: #f1f1f1;
# }
# #T_732b4_row3_col1 {
#   background-color: #f6ebcf;
#   color: #000000;
# }
# #T_732b4_row3_col2 {
#   background-color: #efdcad;
#   color: #000000;
# }
# #T_732b4_row3_col3 {
#   background-color: #64b9ae;
#   color: #f1f1f1;
# }
# #T_732b4_row4_col1, #T_732b4_row4_col2, #T_732b4_row4_col3 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_732b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_732b4_level0_col0" class="col_heading level0 col0" >Market</th>
#       <th id="T_732b4_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_732b4_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_732b4_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_732b4_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_732b4_row0_col0" class="data row0 col0" >Asia Pacific</td>
#       <td id="T_732b4_row0_col1" class="data row0 col1" >4042658.268000</td>
#       <td id="T_732b4_row0_col2" class="data row0 col2" >403176.038000</td>
#       <td id="T_732b4_row0_col3" class="data row0 col3" >48597</td>
#     </tr>
#     <tr>
#       <th id="T_732b4_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_732b4_row1_col0" class="data row1 col0" >Europe</td>
#       <td id="T_732b4_row1_col1" class="data row1 col1" >3287336.233500</td>
#       <td id="T_732b4_row1_col2" class="data row1 col2" >449551.723500</td>
#       <td id="T_732b4_row1_col3" class="data row1 col3" >41919</td>
#     </tr>
#     <tr>
#       <th id="T_732b4_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_732b4_row2_col0" class="data row2 col0" >USCA</td>
#       <td id="T_732b4_row2_col1" class="data row2 col1" >2364129.030300</td>
#       <td id="T_732b4_row2_col2" class="data row2 col2" >304214.411700</td>
#       <td id="T_732b4_row2_col3" class="data row2 col3" >38706</td>
#     </tr>
#     <tr>
#       <th id="T_732b4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_732b4_row3_col0" class="data row3 col0" >LATAM</td>
#       <td id="T_732b4_row3_col1" class="data row3 col1" >2164605.167080</td>
#       <td id="T_732b4_row3_col2" class="data row3 col2" >221643.487080</td>
#       <td id="T_732b4_row3_col3" class="data row3 col3" >38526</td>
#     </tr>
#     <tr>
#       <th id="T_732b4_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_732b4_row4_col0" class="data row4 col0" >Africa</td>
#       <td id="T_732b4_row4_col1" class="data row4 col1" >783773.211000</td>
#       <td id="T_732b4_row4_col2" class="data row4 col2" >88871.631000</td>
#       <td id="T_732b4_row4_col3" class="data row4 col3" >10564</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plotting
plt.figure(figsize=(12, 8))

# Sales plot
plt.subplot(2, 2, 1)
plt.bar(Market_analysis['Market'], Market_analysis['Sales'], color=sns.color_palette('Set1'))
plt.title('Total Sales by Market')
plt.xlabel('Market')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.bar(Market_analysis['Market'], Market_analysis['Profit'], color=sns.color_palette('Set2'))
plt.title('Total Profit by Market')
plt.xlabel('Market')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.bar(Market_analysis['Market'], Market_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.title('Total Quantity by Market')
plt.xlabel('Market')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# The Asia Pacific market emerges as the primary revenue driver, indicating its critical importance in the company's sales strategy and market dominance.
#
# Europe and USCA markets also show significant sales and profit, suggesting opportunities for growth and expansion in these regions.
#
# Understanding sales and profit by market can inform strategic decisions regarding resource allocation, market-specific initiatives, and expansion strategies to optimize performance and maximize profitability.

# %%
##  Group data by Category and calculate sum of Sales, Profit and Quantity
Category_analysis = df.groupby('Category').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).reset_index()

# %%
Category_analysis.sort_values(by='Sales', ascending=False).style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_b7bc2_row0_col1, #T_b7bc2_row0_col2, #T_b7bc2_row2_col3 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_b7bc2_row0_col3, #T_b7bc2_row1_col2, #T_b7bc2_row1_col3, #T_b7bc2_row2_col1 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_b7bc2_row1_col1 {
#   background-color: #e8d097;
#   color: #000000;
# }
# #T_b7bc2_row2_col2 {
#   background-color: #bce5df;
#   color: #000000;
# }
# </style>
# <table id="T_b7bc2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7bc2_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_b7bc2_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_b7bc2_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_b7bc2_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7bc2_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_b7bc2_row0_col0" class="data row0 col0" >Technology</td>
#       <td id="T_b7bc2_row0_col1" class="data row0 col1" >4744557.498080</td>
#       <td id="T_b7bc2_row0_col2" class="data row0 col2" >663778.733180</td>
#       <td id="T_b7bc2_row0_col3" class="data row0 col3" >35176</td>
#     </tr>
#     <tr>
#       <th id="T_b7bc2_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_b7bc2_row1_col0" class="data row1 col0" >Furniture</td>
#       <td id="T_b7bc2_row1_col1" class="data row1 col1" >4110451.898300</td>
#       <td id="T_b7bc2_row1_col2" class="data row1 col2" >285082.730200</td>
#       <td id="T_b7bc2_row1_col3" class="data row1 col3" >34892</td>
#     </tr>
#     <tr>
#       <th id="T_b7bc2_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_b7bc2_row2_col0" class="data row2 col0" >Office Supplies</td>
#       <td id="T_b7bc2_row2_col1" class="data row2 col1" >3787492.513500</td>
#       <td id="T_b7bc2_row2_col2" class="data row2 col2" >518595.827900</td>
#       <td id="T_b7bc2_row2_col3" class="data row2 col3" >108244</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plotting
plt.figure(figsize=(12, 8))

# Sales plot
plt.subplot(2, 2, 1)
plt.bar(Category_analysis['Category'], Category_analysis['Sales'], color=sns.color_palette('Set1'))
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.bar(Category_analysis['Category'], Category_analysis['Profit'], color=sns.color_palette('Set2'))
plt.title('Total Profit by Category')
plt.xlabel('Category')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.bar(Category_analysis['Category'], Category_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.title('Total Quantity by Category')
plt.xlabel('Category')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Technology products contribute significantly to total sales and profit, highlighting their importance in the company's product portfolio and revenue generation.
#
# Office Supplies demonstrate high sales volume but comparatively lower profitability, suggesting potential opportunities for cost optimization or pricing strategies to enhance profitability in this category.

# %%
##  Group data by SUb-Category and calculate sum of Sales, Profit and Quantity
Sub_Category_analysis = df.groupby('Sub-Category').agg({
    'Sales': 'sum',
    'Profit': 'sum',
    'Quantity': 'sum',
}).sort_values(by='Sales', ascending=False).reset_index()

# %%
Sub_Category_analysis.style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_33b5f_row0_col1, #T_33b5f_row1_col2, #T_33b5f_row9_col3 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_33b5f_row0_col2 {
#   background-color: #10746c;
#   color: #f1f1f1;
# }
# #T_33b5f_row0_col3 {
#   background-color: #f5f2ea;
#   color: #000000;
# }
# #T_33b5f_row1_col1 {
#   background-color: #0a6f67;
#   color: #f1f1f1;
# }
# #T_33b5f_row1_col3, #T_33b5f_row15_col2 {
#   background-color: #cc9a4c;
#   color: #f1f1f1;
# }
# #T_33b5f_row2_col1 {
#   background-color: #0e726a;
#   color: #f1f1f1;
# }
# #T_33b5f_row2_col2 {
#   background-color: #aee0d8;
#   color: #000000;
# }
# #T_33b5f_row2_col3 {
#   background-color: #f2f4f4;
#   color: #000000;
# }
# #T_33b5f_row3_col1 {
#   background-color: #187c74;
#   color: #f1f1f1;
# }
# #T_33b5f_row3_col2 {
#   background-color: #7fccc0;
#   color: #000000;
# }
# #T_33b5f_row3_col3, #T_33b5f_row14_col2 {
#   background-color: #dbb972;
#   color: #000000;
# }
# #T_33b5f_row4_col1 {
#   background-color: #a6dcd4;
#   color: #000000;
# }
# #T_33b5f_row4_col2 {
#   background-color: #e6f1f0;
#   color: #000000;
# }
# #T_33b5f_row4_col3 {
#   background-color: #58b0a7;
#   color: #f1f1f1;
# }
# #T_33b5f_row5_col1 {
#   background-color: #d4ede9;
#   color: #000000;
# }
# #T_33b5f_row5_col2 {
#   background-color: #abdfd7;
#   color: #000000;
# }
# #T_33b5f_row5_col3 {
#   background-color: #ab6e1f;
#   color: #f1f1f1;
# }
# #T_33b5f_row6_col1 {
#   background-color: #f6ecd3;
#   color: #000000;
# }
# #T_33b5f_row6_col2 {
#   background-color: #f1e1b5;
#   color: #000000;
# }
# #T_33b5f_row6_col3 {
#   background-color: #8b500a;
#   color: #f1f1f1;
# }
# #T_33b5f_row7_col1 {
#   background-color: #f6ebcd;
#   color: #000000;
# }
# #T_33b5f_row7_col2, #T_33b5f_row7_col3, #T_33b5f_row16_col1 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_33b5f_row8_col1 {
#   background-color: #f6eac9;
#   color: #000000;
# }
# #T_33b5f_row8_col2 {
#   background-color: #c7eae5;
#   color: #000000;
# }
# #T_33b5f_row8_col3 {
#   background-color: #f6ecd1;
#   color: #000000;
# }
# #T_33b5f_row9_col1 {
#   background-color: #ca9849;
#   color: #f1f1f1;
# }
# #T_33b5f_row9_col2 {
#   background-color: #f6ebcf;
#   color: #000000;
# }
# #T_33b5f_row10_col1 {
#   background-color: #b97b29;
#   color: #f1f1f1;
# }
# #T_33b5f_row10_col2 {
#   background-color: #e9d39d;
#   color: #000000;
# }
# #T_33b5f_row10_col3 {
#   background-color: #f6edd7;
#   color: #000000;
# }
# #T_33b5f_row11_col1 {
#   background-color: #b57826;
#   color: #f1f1f1;
# }
# #T_33b5f_row11_col2, #T_33b5f_row13_col2 {
#   background-color: #f1dfb3;
#   color: #000000;
# }
# #T_33b5f_row11_col3 {
#   background-color: #73c3b8;
#   color: #000000;
# }
# #T_33b5f_row12_col1, #T_33b5f_row13_col1 {
#   background-color: #8d520b;
#   color: #f1f1f1;
# }
# #T_33b5f_row12_col2 {
#   background-color: #d4ac62;
#   color: #000000;
# }
# #T_33b5f_row12_col3 {
#   background-color: #ddbe78;
#   color: #000000;
# }
# #T_33b5f_row13_col3 {
#   background-color: #ebf3f2;
#   color: #000000;
# }
# #T_33b5f_row14_col1 {
#   background-color: #754308;
#   color: #f1f1f1;
# }
# #T_33b5f_row14_col3 {
#   background-color: #d8b46c;
#   color: #000000;
# }
# #T_33b5f_row15_col1 {
#   background-color: #583305;
#   color: #f1f1f1;
# }
# #T_33b5f_row15_col3 {
#   background-color: #e5cc8f;
#   color: #000000;
# }
# #T_33b5f_row16_col2 {
#   background-color: #cd9d50;
#   color: #f1f1f1;
# }
# #T_33b5f_row16_col3 {
#   background-color: #e8d097;
#   color: #000000;
# }
# </style>
# <table id="T_33b5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33b5f_level0_col0" class="col_heading level0 col0" >Sub-Category</th>
#       <th id="T_33b5f_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_33b5f_level0_col2" class="col_heading level0 col2" >Profit</th>
#       <th id="T_33b5f_level0_col3" class="col_heading level0 col3" >Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33b5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33b5f_row0_col0" class="data row0 col0" >Phones</td>
#       <td id="T_33b5f_row0_col1" class="data row0 col1" >1706824.139200</td>
#       <td id="T_33b5f_row0_col2" class="data row0 col2" >216717.005800</td>
#       <td id="T_33b5f_row0_col3" class="data row0 col3" >11870</td>
#     </tr>
#     <tr>
#       <th id="T_33b5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33b5f_row1_col0" class="data row1 col0" >Copiers</td>
#       <td id="T_33b5f_row1_col1" class="data row1 col1" >1509436.273280</td>
#       <td id="T_33b5f_row1_col2" class="data row1 col2" >258567.548180</td>
#       <td id="T_33b5f_row1_col3" class="data row1 col3" >7454</td>
#     </tr>
#     <tr>
#       <th id="T_33b5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_33b5f_row2_col0" class="data row2 col0" >Chairs</td>
#       <td id="T_33b5f_row2_col1" class="data row2 col1" >1501681.764200</td>
#       <td id="T_33b5f_row2_col2" class="data row2 col2" >140396.267500</td>
#       <td id="T_33b5f_row2_col3" class="data row2 col3" >12336</td>
#     </tr>
#     <tr>
#       <th id="T_33b5f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_33b5f_row3_col0" class="data row3 col0" >Bookcases</td>
#       <td id="T_33b5f_row3_col1" class="data row3 col1" >1466572.241800</td>
#       <td id="T_33b5f_row3_col2" class="data row3 col2" >161924.419500</td>
#       <td id="T_33b5f_row3_col3" class="data row3 col3" >8310</td>
#     </tr>
#     <tr>
#       <th id="T_33b5f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_33b5f_row4_col0" class="data row4 col0" >Storage</td>
#       <td id="T_33b5f_row4_col1" class="data row4 col1" >1126812.969400</td>
#       <td id="T_33b5f_row4_col2" class="data row4 col2" >108416.680600</td>
#       <td id="T_33b5f_row4_col3" class="data row4 col3" >16884</td>
#     </tr>
#     <tr>
#       <th id="T_33b5f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_33b5f_row5_col0" class="data row5 col0" >Appliances</td>
#       <td id="T_33b5f_row5_col1" class="data row5 col1" >1010535.525000</td>
#       <td id="T_33b5f_row5_col2" class="data row5 col2" >141562.587700</td>
#       <td id="T_33b5f_row5_col3" class="data row5 col3" >6026</td>
#     </tr>
#     <tr>
#       <th id="T_33b5f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_33b5f_row6_col0" class="data row6 col0" >Machines</td>
#       <td id="T_33b5f_row6_col1" class="data row6 col1" >779060.067100</td>
#       <td id="T_33b5f_row6_col2" class="data row6 col2" >58867.873000</td>
#       <td id="T_33b5f_row6_col3" class="data row6 col3" >4906</td>
#     </tr>
#     <tr>
#       <th id="T_33b5f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_33b5f_row7_col0" class="data row7 col0" >Tables</td>
#       <td id="T_33b5f_row7_col1" class="data row7 col1" >757041.924400</td>
#       <td id="T_33b5f_row7_col2" class="data row7 col2" >-64083.388700</td>
#       <td id="T_33b5f_row7_col3" class="data row7 col3" >3083</td>
#     </tr>
#     <tr>
#       <th id="T_33b5f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_33b5f_row8_col0" class="data row8 col0" >Accessories</td>
#       <td id="T_33b5f_row8_col1" class="data row8 col1" >749237.018500</td>
#       <td id="T_33b5f_row8_col2" class="data row8 col2" >129626.306200</td>
#       <td id="T_33b5f_row8_col3" class="data row8 col3" >10946</td>
#     </tr>
#     <tr>
#       <th id="T_33b5f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_33b5f_row9_col0" class="data row9 col0" >Binders</td>
#       <td id="T_33b5f_row9_col1" class="data row9 col1" >461869.393700</td>
#       <td id="T_33b5f_row9_col2" class="data row9 col2" >72433.151600</td>
#       <td id="T_33b5f_row9_col3" class="data row9 col3" >21403</td>
#     </tr>
#     <tr>
#       <th id="T_33b5f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_33b5f_row10_col0" class="data row10 col0" >Furnishings</td>
#       <td id="T_33b5f_row10_col1" class="data row10 col1" >385155.967900</td>
#       <td id="T_33b5f_row10_col2" class="data row10 col2" >46845.431900</td>
#       <td id="T_33b5f_row10_col3" class="data row10 col3" >11163</td>
#     </tr>
#     <tr>
#       <th id="T_33b5f_level0_row11" class="row_heading level0 row11" >11</th>

# %%
# Plotting
plt.figure(figsize=(12, 8))

# Sales plot
plt.subplot(2, 2, 1)
plt.bar(Sub_Category_analysis['Sub-Category'], Sub_Category_analysis['Sales'], color=sns.color_palette('Set1'))
plt.xticks(rotation=90)
plt.title('Total Sales by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Total Sales')

# Profit plot
plt.subplot(2, 2, 2)
plt.bar(Sub_Category_analysis['Sub-Category'], Sub_Category_analysis['Profit'], color=sns.color_palette('Set2'))
plt.xticks(rotation=90)
plt.title('Total Profit by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Total Profit')

# Quantity plot
plt.subplot(2, 2, 3)
plt.bar(Sub_Category_analysis['Sub-Category'], Sub_Category_analysis['Quantity'], color=sns.color_palette('Set3'))
plt.xticks(rotation=90)
plt.title('Total Quantity by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Total Quantity Sold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Sub-categories like Phones, Copiers, and Chairs demonstrate strong sales performance and profitability, suggesting potential growth opportunities or competitive advantages in their respective markets.
#
# Addressing challenges in sub-categories like Tables, where profitability is negative, may require review or adjustment of pricing strategies, cost structures, or product offerings to improve performance and sustainability.

# %%
Sub_Category_analysis.query('Quantity == Quantity.max()')
# Out:
#   Sub-Category      Sales    Profit  Quantity
# 9      Binders 461,869.39 72,433.15     21403

# %% [markdown]
# Binders emerge as the most sold sub-category, indicating high demand or popularity among customers.

# %%
## Getting the number of returns by Product ID 
Return_analysis = df.groupby('Product ID').agg({
    'Returned': 'count',
}).sort_values(by='Returned', ascending=False)

# %%
Return_analysis.head(10).style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_24362_row0_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_24362_row1_col0 {
#   background-color: #955910;
#   color: #f1f1f1;
# }
# #T_24362_row2_col0 {
#   background-color: #8d520b;
#   color: #f1f1f1;
# }
# #T_24362_row3_col0 {
#   background-color: #774508;
#   color: #f1f1f1;
# }
# #T_24362_row4_col0 {
#   background-color: #754308;
#   color: #f1f1f1;
# }
# #T_24362_row5_col0 {
#   background-color: #6a3d07;
#   color: #f1f1f1;
# }
# #T_24362_row6_col0 {
#   background-color: #5f3606;
#   color: #f1f1f1;
# }
# #T_24362_row7_col0, #T_24362_row8_col0 {
#   background-color: #563105;
#   color: #f1f1f1;
# }
# #T_24362_row9_col0 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_24362">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24362_level0_col0" class="col_heading level0 col0" >Returned</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product ID</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24362_level0_row0" class="row_heading level0 row0" >OFF-FA-6129</th>
#       <td id="T_24362_row0_col0" class="data row0 col0" >227</td>
#     </tr>
#     <tr>
#       <th id="T_24362_level0_row1" class="row_heading level0 row1" >OFF-BI-3737</th>
#       <td id="T_24362_row1_col0" class="data row1 col0" >92</td>
#     </tr>
#     <tr>
#       <th id="T_24362_level0_row2" class="row_heading level0 row2" >OFF-ST-4057</th>
#       <td id="T_24362_row2_col0" class="data row2 col0" >90</td>
#     </tr>
#     <tr>
#       <th id="T_24362_level0_row3" class="row_heading level0 row3" >OFF-ST-5693</th>
#       <td id="T_24362_row3_col0" class="data row3 col0" >84</td>
#     </tr>
#     <tr>
#       <th id="T_24362_level0_row4" class="row_heading level0 row4" >OFF-BI-4828</th>
#       <td id="T_24362_row4_col0" class="data row4 col0" >83</td>
#     </tr>
#     <tr>
#       <th id="T_24362_level0_row5" class="row_heading level0 row5" >OFF-AR-5923</th>
#       <td id="T_24362_row5_col0" class="data row5 col0" >80</td>
#     </tr>
#     <tr>
#       <th id="T_24362_level0_row6" class="row_heading level0 row6" >OFF-ST-6033</th>
#       <td id="T_24362_row6_col0" class="data row6 col0" >77</td>
#     </tr>
#     <tr>
#       <th id="T_24362_level0_row7" class="row_heading level0 row7" >OFF-BI-2917</th>
#       <td id="T_24362_row7_col0" class="data row7 col0" >75</td>
#     </tr>
#     <tr>
#       <th id="T_24362_level0_row8" class="row_heading level0 row8" >OFF-AR-6120</th>
#       <td id="T_24362_row8_col0" class="data row8 col0" >75</td>
#     </tr>
#     <tr>
#       <th id="T_24362_level0_row9" class="row_heading level0 row9" >OFF-BI-3293</th>
#       <td id="T_24362_row9_col0" class="data row9 col0" >74</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Product ID: OFF-FA-6129:
#
# Records the highest number of returns, totaling 227 units.
#
# Understanding the products with the highest number of returns can provide valuable insights into potential quality issues, customer preferences, or market trends.

# %%
discount_analysis = df.groupby('Discount').agg({'Sales': 'mean', 'Profit': 'mean'}).reset_index().sort_values(by='Sales', ascending=False).style.background_gradient(cmap='Blues')
discount_analysis
# Out:
# <style type="text/css">
# #T_88710_row0_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_88710_row0_col1, #T_88710_row0_col2, #T_88710_row10_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_88710_row1_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_88710_row1_col1 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_88710_row1_col2 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_88710_row2_col0, #T_88710_row5_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_88710_row2_col1, #T_88710_row25_col0 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_88710_row2_col2 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_88710_row3_col0 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_88710_row3_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_88710_row3_col2 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_88710_row4_col0, #T_88710_row10_col2, #T_88710_row16_col0, #T_88710_row26_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_88710_row4_col1 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_88710_row4_col2 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_88710_row5_col0, #T_88710_row20_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_88710_row5_col2 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_88710_row6_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_88710_row6_col1 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_88710_row6_col2 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_88710_row7_col0 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_88710_row7_col1 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_88710_row7_col2 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_88710_row8_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_88710_row8_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_88710_row8_col2 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_88710_row9_col0, #T_88710_row12_col1 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_88710_row9_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_88710_row9_col2 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_88710_row10_col1 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_88710_row11_col0, #T_88710_row16_col1, #T_88710_row17_col0, #T_88710_row17_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_88710_row11_col1 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_88710_row11_col2 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_88710_row12_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_88710_row12_col2 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_88710_row13_col0 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_88710_row13_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_88710_row13_col2 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_88710_row14_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_88710_row14_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_88710_row14_col2, #T_88710_row26_col0 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_88710_row15_col0 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_88710_row15_col1 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_88710_row15_col2 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_88710_row16_col2 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_88710_row17_col2 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_88710_row18_col0 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_88710_row18_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_88710_row18_col2 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_88710_row19_col0 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_88710_row19_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_88710_row19_col2 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_88710_row20_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_88710_row20_col2 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_88710_row21_col0 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_88710_row21_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_88710_row21_col2, #T_88710_row22_col2 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_88710_row22_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_88710_row22_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_88710_row23_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_88710_row23_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_88710_row23_col2 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_88710_row24_col0 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_88710_row24_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_88710_row24_col2 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_88710_row25_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_88710_row25_col2 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_88710_row26_col2 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_88710">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88710_level0_col0" class="col_heading level0 col0" >Discount</th>
#       <th id="T_88710_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_88710_level0_col2" class="col_heading level0 col2" >Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88710_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_88710_row0_col0" class="data row0 col0" >0.070000</td>
#       <td id="T_88710_row0_col1" class="data row0 col1" >810.779022</td>
#       <td id="T_88710_row0_col2" class="data row0 col2" >140.990022</td>
#     </tr>
#     <tr>
#       <th id="T_88710_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_88710_row1_col0" class="data row1 col0" >0.350000</td>
#       <td id="T_88710_row1_col1" class="data row1 col1" >784.479406</td>
#       <td id="T_88710_row1_col2" class="data row1 col2" >-116.144693</td>
#     </tr>
#     <tr>
#       <th id="T_88710_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_88710_row2_col0" class="data row2 col0" >0.570000</td>
#       <td id="T_88710_row2_col1" class="data row2 col1" >678.733500</td>
#       <td id="T_88710_row2_col2" class="data row2 col2" >-526.129000</td>
#     </tr>
#     <tr>
#       <th id="T_88710_level0_row3" class="row_heading level0 row3" >19</th>
#       <td id="T_88710_row3_col0" class="data row3 col0" >0.550000</td>
#       <td id="T_88710_row3_col1" class="data row3 col1" >630.865800</td>
#       <td id="T_88710_row3_col2" class="data row3 col2" >-315.067200</td>
#     </tr>
#     <tr>
#       <th id="T_88710_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_88710_row4_col0" class="data row4 col0" >0.002000</td>
#       <td id="T_88710_row4_col1" class="data row4 col1" >567.018701</td>
#       <td id="T_88710_row4_col2" class="data row4 col2" >125.762649</td>
#     </tr>
#     <tr>
#       <th id="T_88710_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_88710_row5_col0" class="data row5 col0" >0.150000</td>
#       <td id="T_88710_row5_col1" class="data row5 col1" >565.674387</td>
#       <td id="T_88710_row5_col2" class="data row5 col2" >50.602409</td>
#     </tr>
#     <tr>
#       <th id="T_88710_level0_row6" class="row_heading level0 row6" >10</th>
#       <td id="T_88710_row6_col0" class="data row6 col0" >0.300000</td>
#       <td id="T_88710_row6_col1" class="data row6 col1" >555.682421</td>
#       <td id="T_88710_row6_col2" class="data row6 col2" >-57.899557</td>
#     </tr>
#     <tr>
#       <th id="T_88710_level0_row7" class="row_heading level0 row7" >11</th>
#       <td id="T_88710_row7_col0" class="data row7 col0" >0.320000</td>
#       <td id="T_88710_row7_col1" class="data row7 col1" >536.794770</td>
#       <td id="T_88710_row7_col2" class="data row7 col2" >-88.560656</td>
#     </tr>
#     <tr>
#       <th id="T_88710_level0_row8" class="row_heading level0 row8" >8</th>
#       <td i

# %%
# Group data by 'Discount' and calculate average sales and profit for each group
discount_analysis = df.groupby('Discount').agg({'Sales': 'mean', 'Profit': 'mean'}).reset_index()

# Melt and plot the DataFrame
plt.figure(figsize=(10, 6))
sns.barplot(x='Discount', y='value', hue='variable', data=pd.melt(discount_analysis, id_vars='Discount'), palette='muted')

# Adding labels and title
plt.xticks(rotation=90)
plt.xlabel('Discount Presence')
plt.ylabel('Average Value')
plt.title('Effect of Discounts on Sales and Profit')

# Display the plot
plt.show()

# %% [markdown]
# Discounts can drive sales volume but may not always translate into increased profitability, as seen in cases of high discounts resulting in negative profits.
#
# Analyzing the impact of discounts on sales and profit can help in optimizing pricing strategies to balance revenue generation and profit margins effectively.
#
# Identifying the most effective discount levels that maximize sales while maintaining acceptable profit margins is crucial for sustainable business growth.

# %%
# Grouping the count of order priority by ship mode 
order_analysis = df.groupby('Ship Mode').agg({
    'Order Priority': 'count',
}).sort_values(by='Order Priority', ascending=False).reset_index()
order_analysis
# Out:
#         Ship Mode  Order Priority
# 0  Standard Class           30775
# 1    Second Class           10309
# 2     First Class            7505
# 3        Same Day            2701

# %% [markdown]
# Standard Class appears to be the most commonly chosen shipping option, suggesting it may be the most cost-effective or efficient for most orders.

# %% [markdown]
# ### Summary and Conclusion:
#
# **Sales and Profitability:**
# Sales and profitability have consistently grown over the years, with notable increases seen in 2014 and 2015.
#
# The technology category leads in sales, followed by furniture and office supplies.
#
# Phones, copiers, and chairs are the top-selling sub-categories, making significant contributions to overall sales and profits.
#
# Binders and office furniture (FUR-CH) are the highest-selling products, indicating strong demand in these areas.
#
# **Customer Segments and Regions:**
# The consumer segment generates the highest sales and profits, followed by the corporate and home office segments.
#
# Western Europe, Central America, and Oceania are the top-performing regions in terms of sales and profits, highlighting potential opportunities for expansion or greater focus.
#
# **Shipping Dynamics:**
# Standard class shipping is the most popular choice, emphasizing the importance of cost-effective delivery options for customers.
#
# The majority of orders are categorized as medium priority, balancing cost with delivery speed.
#
# **Discount and Return Analysis:**
# The majority of orders are made without discounts, suggesting competitive pricing strategies or limited promotional efforts.
#
# The return rate is low, with most products not being returned, indicating high product quality or effective customer service.
#
# **Future Protocol:**
# Establish a protocol for ongoing analysis of sales and profitability, with a focus on segment and regional performance.
#
# Optimize shipping expenses through strategic planning and the use of technology.
#
# Improve customer experience with personalized communication and regular feedback collection.
#
# Stay adaptable and responsive to shifting market trends and consumer preferences.
#
# ---
#
# ### Conclusion:
# A thorough understanding of sales, profitability, and shipping trends is essential for making informed business decisions and improving operational efficiency. By leveraging these insights, businesses can enhance customer satisfaction, streamline logistics, and ultimately drive greater profitability.
